# %% [markdown]
# <a href="https://colab.research.google.com/github/KudaDanz/Kuda-Danzvara-Weekly-Lab-Tickets/blob/main/Developer's_Diary_(3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screenshot 2026-05-02 190837.png](data:image/png;base64,...)

# %% [markdown]
# ![improved.png](data:image/png;base64,...)

# %%
#Artifact:

#My Initial Prompt: I needed to understand the basics before I could proceed with the assignment.
#                   I prompted Microsoft Copilot to expalin CSV files as if it were explaining to
#                   a child to be able to get a simple explanation.

#My Improved Prompt: After understanding the gist of CSV files, my improved prompt was centered on
#                    receiving AI generated sample transaction data with various spending categories.

#Context:  Buiding on AI prompts, making them more specific to receive improved output.

#Reflection:  The first promtp I used genberated a generic output. I did however, understand the
#             the basic gist of the explanation. My improved prompt assisted with putting the response
#             into perspective and only then did the generated output match with a more rounded and
#             precise meaning.

# %% [markdown]
# ![Screenshot 2026-05-20 115157.png](data:image/png;base64,...)

# %%
#Artifact Today
#         You said:




#Give me 3 realistic examples of Australian transaction data with different
#scenarios (normal spending, refunds, large purchases). Show me how to manually
#calculate meaningful financial insights from each scenario.
#Copilot said:
#Copilot
#Great — this is exactly the kind of thinking your assignment is looking for 👍
#I’ll give you 3 realistic Australian scenarios and then manually calculate insights step by step so you can show your understanding.

#✅ Scenario 1: Normal Everyday Spending
#📄 Data (CSV-style)



#CSV
#Date,Description,Category,Amount (AUD)
#026-03-01,Woolworths,Groceries,85.40
#2026-03-02,Opal Card,Transport,9.80
#2026-03-03,Grill'd,Food & Drink,32.50
#2026-03-04,Telstra,Utilities,65.00
#``
#🧮 Manual Calculations
#1. Total Spending
#Add all amounts:

#85.40 + 9.80 + 32.50 + 65.00 = 192.70
#✅ Total Spending = $192.70

#2. Spending by Category
#Groceries → 85.40
#ransport → 9.80
#Food & Drink → 32.50
#3Utilities → 65.00
#3. Highest Spending Category
#Compare values:

#Highest = Groceries ($85.40)
#4. Insight
#👉 “Most money is spent on groceries (44% of total spending)”

#Calculation:

#85.40 ÷ 192.70 ≈ 0.44 (44%)
#✅ ✅ Meaningful Insight

#User spends the most on essential items (groceries)
#Spending looks balanced and normal


#My Initial Prompt :Can you generate 3 different types of CSV sets of data tailored to Australian businesses.

#My Improved Prompt :Give me 3 realistic examples of Australian transaction data with different
#scenarios (normal spending, refunds, large purchases). Show me how to manually
#calculate meaningful financial insights from each scenario.
#Generate two more transaction data sets. Tailor the description to Australian businesses.

#Context : A misguided prompt produces an output that is not comprehensible and inconclusive. It becomes difficult and quite senseless
#          to merge that data with the progression of building a smart application.

#Reflection : After receiving data that I could work with by hand to understand the logic, it was quite a straightforward process.
#             I followed the example given, and worked out the problems manually 3 times and understood the way in which the
#             application is supposed to function
